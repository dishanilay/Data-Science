# %%
# !pip install bs4
# !pip install requests

# %%
from bs4 import BeautifulSoup
import requests

# %%
#solution1
page = requests.get('https://www.wikipedia.org/')

# %%
soup = BeautifulSoup(page.content)
soup
# Out:
# <!DOCTYPE html>
# <html class="no-js" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>Wikipedia</title>
# <meta content="Wikipedia is a free online encyclopedia, created and edited by volunteers around the world and hosted by the Wikimedia Foundation." name="description"/>
# <script>
# document.documentElement.className = document.documentElement.className.replace( /(^|\s)no-js(\s|$)/, "$1js-enabled$2" );
# </script>
# <meta content="initial-scale=1,user-scalable=yes" name="viewport"/>
# <link href="/static/apple-touch/wikipedia.png" rel="apple-touch-icon"/>
# <link href="/static/favicon/wikipedia.ico" rel="shortcut icon"/>
# <link href="//creativecommons.org/licenses/by-sa/4.0/" rel="license"/>
# <style>
# ...

# %%
page
# Out:
# <Response [200]>

# %%
#solution2=page not found
page = requests.get('https://presidentofindia.nic.in/former-presidents.htm')
page
# Out:
# <Response [404]>

# %%
first_tag = soup.find(['h1','h2','h3','h4','h5'])
first_tag
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 first_tag = soup.find(['h1','h2','h3','h4','h5'])
#       2 first_tag
#
# NameError: name 'soup' is not defined

# %%
first_tag.text
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 first_tag.text
#
# NameError: name 'first_tag' is not defined

# %%
#solution3
page = requests.get('https://www.icc-cricket.com/rankings/mens/player-rankings/test')
page
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(page.content)
soup
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <meta content="ICC Men's Test Player Rankings | ICC" name="twitter:title"/>
# <meta content="website" property="og:type"/>
# <meta content="summary_large_image" property="twitter:card"/>
# <meta content="Official International Cricket Council rankings for test match cricket players. Discover latest ICC rankings table, predict upcoming matches, see points and ratings for all teams." name="description"/>
# <meta content="@icc" property="twitter:site"/>
# <meta content="Official International Cricket Council rankings for test match cricket players. Discover latest ICC rankings table, predict upcoming matches, see points and ratings for all teams." name="twitter:description"/>
# <meta content="https://www.icc-cricket.com/resources/ver/i/elements/default-thumbnail.jpg" name="twitter:image"/>
# <meta content="ICC Men's Test Player Rankings | ICC" property="og:title"/>
# ...

# %%
topten=soup.find('div',class_="td",table-body__cell u-center-text")
topten
# Out:
#   Cell In[19], line 1
#     topten=soup.find('div',class_="td",table-body__cell u-center-text")
#                                                                      ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
#solution5
page = requests.get('https://www.cnbc.com/world/?region=world')
page
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(page.content)
soup
# Out:
# <!DOCTYPE html>
# ...

# %%
#solution6
page = requests.get('https://www.journals.elsevier.com/artificial-intelligence/most-downloaded-articles')
page
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(page.content)
soup
# Out:
# <!DOCTYPE html>
# <html>
# <head>
# <title>Food not found or not serving in your area | Dineout</title>
# <meta content="noindex, nofollow" name="robots"/>
# <link href="https://www.dineout.co.in/static/img/favicon.ico" rel="icon" type="image/x-icon"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <style type="text/css">
# 	    * {
# 	        margin: 0;
# 	        padding: 0;
# 	    }
#
# 	    html,
# 	    body {
# 	        height: 100%;
# 	    }
#
# 	    body {
# 	        background: url(https://im1.dineout.co.in/images/uploads/misc/2020/Aug/5/mask_group.png) left top no-repeat #fff;
# 	        background-size: cover;
# 	        font-family: Arial, Helvetica, sans-serif;
# 	        font-size: 14px;
# 	    }
#
# 	    .container {
# 	        max-width: 400px;
# 	        margin: 0 auto;
# 	        width: 100%;
# 	        text-align: center;
# 	        padding-top: 10%;
# 	    }
#
# 	    img {
# 	        max-width: 100%;
# 	        height: auto;
# ...

# %%
#solution7
page = requests.get('https://www.dineout.co.in/')
page
# Out:
# <Response [200]>

# %%
soup=BeautifulSoup(page.content)
soup
# Out:
# <!DOCTYPE html>
# <html>
# <head>
# <title>Food not found or not serving in your area | Dineout</title>
# <meta content="noindex, nofollow" name="robots"/>
# <link href="https://www.dineout.co.in/static/img/favicon.ico" rel="icon" type="image/x-icon"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <style type="text/css">
# 	    * {
# 	        margin: 0;
# 	        padding: 0;
# 	    }
#
# 	    html,
# 	    body {
# 	        height: 100%;
# 	    }
#
# 	    body {
# 	        background: url(https://im1.dineout.co.in/images/uploads/misc/2020/Aug/5/mask_group.png) left top no-repeat #fff;
# 	        background-size: cover;
# 	        font-family: Arial, Helvetica, sans-serif;
# 	        font-size: 14px;
# 	    }
#
# 	    .container {
# 	        max-width: 400px;
# 	        margin: 0 auto;
# 	        width: 100%;
# 	        text-align: center;
# 	        padding-top: 10%;
# 	    }
#
# 	    img {
# 	        max-width: 100%;
# 	        height: auto;
# ...

# %%
#cant find the solution.get the error like food not serving in your area.
